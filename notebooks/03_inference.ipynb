# %% [markdown]
# # Inference Results Visualization
#
# This notebook loads trained models, runs inference, and visualizes predictions with overlays.

# %%
import sys
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt
import nibabel as nib

sys.path.insert(0, str(Path.cwd().parent))

from src.modeling.inference import load_trained_model, predict_volume
from src.preprocessing.transforms import get_inference_transforms
