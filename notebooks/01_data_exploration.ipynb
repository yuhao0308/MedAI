# %% [markdown]
# # Data Exploration
#
# This notebook explores the BIDS dataset structure, visualizes sample images and labels, and displays data statistics.

# %%
import sys
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt
import nibabel as nib

# Add src to path
sys.path.insert(0, str(Path.cwd().parent))

from src.preprocessing.dataloader import read_bids_dataset
from src.visualization.viewer_utils import visualize_nifti_slices

# %%
# Load BIDS dataset
bids_root = "../data/bids_dataset"
data_dicts = read_bids_dataset(bids_root)
print(f"Found {len(data_dicts)} image-label pairs")
